# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd
import numpy as np
from sklearn import datasets

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import mlflow

from mlflow.models import infer_signature

# %%
# set the tracking uri

mlflow.set_tracking_uri("https://127.0.0.1:5000")

# %%
# load the dataset

X,y = datasets.load_iris(return_X_y=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.20)

# %%
params = {"penalty":"l2","solver": "lbfgs", "max_iter":1000, "multi_class":"auto", "random_state":8888}

# %%
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=8888)

# %%
y_pred = lr.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred )

# %% [markdown]
# # MLflow Tracking

# %%
import mlflow
import mlflow.artifacts

mlflow.set_tracking_uri(uri = "http://127.0.0.1:5000")
mlflow.set_experiment("MLFlow QuickStart")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.set_tag("Training Info", "Basic LR model for Iris data")
    
    signature = infer_signature(X_train, lr.predict(X_train))
    
    mlflow.sklearn.log_model(
        sk_model = lr,
        signature = signature,
        input_example = X_train,
        registered_model_name = "Tracking-quickstart",
        artifact_path = "iris_model"
    )
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# Successfully registered model 'Tracking-quickstart'.
# 2024/12/11 23:47:56 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Tracking-quickstart, version 1
# 🏃 View run funny-vole-881 at: http://127.0.0.1:5000/#/experiments/716835318300031499/runs/fcdb025fc3a64a5c8c6fabf5aa6be1a0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/716835318300031499
# Created version '1' of model 'Tracking-quickstart'.
